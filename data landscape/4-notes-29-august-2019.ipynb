# %% [markdown]
# # Product Ownership, Agile, and data w. Danny Mallas Pereira from Spotify
#
# **Agile Coaching**
#
# *Deliver OUTCOMES not OUTPUT*
#
# **Diversity & Beloning Lead**
#
# *culture*
#
# **Product Management**
#
# Responsible for the success of the product
#
# ![1](./images/product-manager.jpg)
#
# The Cynefin Framework
#
# Simple - Sense, cateorise, respons, best practice
#
# Complictated -
#
#
#
# Double Diamond
#
# ![1](./images/double-diamond.jpg)
#
# Think it - Build it - Ship it - Teak it
#
# Think it
#
# **Research**
# - Problem validation
# - Concept validation
# - Experimation
# - Throw away code
# - Throw away design
# - Business case
#
# **Build it**
# - MVP Scoping
# - Architecture
# - Quality code
# - Quality design
# - Test automation
#
# **Ship it**
# - Everything instrumation
# - Analytics
# - Ablity to measure how people interact with your product
#
#
# **Tweak it**
# - Optimization
# - Cost reduction
# - Maintenance
# - Support
# - User feedback
#
# s
